# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Data analyst Data.csv")
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
df.drop_duplicates()
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
# 1. Unique students in the dataset

df.dropna(inplace = True)

# new data frame with split value columns
new = df["First Name"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df["First Name1"]= new[0]
 
# making separate last name column from new data frame
df["Last Name1"]= new[1]
 
# Dropping old Name columns
df.drop(columns =["First Name"], inplace = True)
 
# df display
df
# Out:
#                Email ID  Quantity                       Events  \
# 1     dhanshree@xyz.com         1       Art of Resume Building
# 8      mayuresh@xyz.com         1       Art of Resume Building
# 18      shubham@xyz.com         1       Art of Resume Building
# 20      shivani@xyz.com         1       Art of Resume Building
# 27    dhanshree@xyz.com         1       Art of Resume Building
# ...                 ...       ...                          ...
# 4406      derek@xyz.com         1  Product Design & Full Stack
# 4410    louella@xyz.com         1  Product Design & Full Stack
# 4447    claudia@xyz.com         1  Product Design & Full Stack
# 4464    leeanne@xyz.com         1  Product Design & Full Stack
# 4488       veta@xyz.com         1  Product Design & Full Stack
#
#      Attendee Status                                       College Name  \
# 1          Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
df['First Name1'].unique()
# Out:
# array(['Dhanshree', 'Mayuresh', 'Shubham', 'Shivani', 'Harsh', 'Sanika',
#        'Shweta', 'Vaishnavi', 'Rutuja', 'Supriya', 'Nisha', 'Rehan',
#        'Sonal', 'Dinesh', 'Rajkumar', 'Priyanka', 'Samiksha', 'Vishal',
#        'Rahul', 'Sayali', 'Manisha', 'Bhushan', 'Ganesh', 'Sharvari',
#        'Archana', 'Shubhangi', 'Mayuri', 'Anuja', 'Pooja', 'Simran',
#        'Aryan', 'Sushmita', 'Pallavi', 'Yogesh', 'Snehal', 'Rajesh',
#        'Akash', 'Gaurav', 'Girish', 'PRIYANSHI', 'Keri', 'Robert',
#        'David', 'Leona', 'Leonard', 'Marianne', 'John', 'Marvin',
#        'Christine', 'Brian', 'Jennifer', 'Rosa', 'Tammy', 'Bonnie',
#        'Margaret', 'Patel', 'Aswini', 'Ankita', 'Surya', 'Esha', 'Vrinda',
#        'subhashchandra', 'Hanmant', 'Viki', 'Neeta', 'savio', 'Pradeep',
#        'Prathit', 'Nashra', 'Poonam', 'REJOICE', 'Kanchan', 'Ruchira',
#        'Derek', 'Louella', 'Claudia', 'Leeanne', 'Veta'], dtype=object)

# %%
# 2 Avg Gpa of students
e=df['CGPA']/10*100
r=e/100*4
r.tolist()
# Out:
# [3.28,
#  3.44,
#  3.6399999999999992,
#  3.8,
#  3.56,
#  2.76,
#  2.92,
#  2.68,
#  3.4,
#  3.76,
#  3.08,
#  3.2,
#  2.6,
#  3.76,
#  2.68,
#  2.68,
#  3.16,
#  3.4799999999999995,
#  3.72,
#  2.96,
#  3.28,
#  3.8,
#  3.68,
#  3.8,
#  3.76,
#  3.4,
#  3.08,
#  3.16,
#  3.04,
#  3.6399999999999992,
#  2.76,
#  2.92,
#  3.72,
#  3.12,
#  3.16,
#  2.88,
#  2.84,
#  2.72,
#  2.92,
#  3.32,
#  2.52,
#  2.76,
#  3.88,
#  2.92,
#  3.84,
#  3.0,
#  3.0,
#  3.4799999999999995,
#  2.96,
#  3.96,
#  3.4,
#  3.6399999999999992,
#  2.92,
#  3.16,
#  3.72,
#  3.04,
#  3.4,
#  2.92,
#  3.4,
#  2.52,
#  2.92,
#  2.6,
#  3.72,
#  3.3600000000000008,
#  2.6399999999999992,
#  3.6399999999999992,
#  3.32,
#  3.4799999999999995,
#  3.56,
#  3.04,
#  3.32,
#  3.44,
#  3.6399999999999992,
#  3.2,
#  2.56,
#  3.4799999999999995,
#  3.96,
#  2.92,
#  3.76,
#  3.76,
#  3.04,
#  3.04,
#  2.76,
#  3.68,
#  3.32,
#  2.6,
#  2.84]

# %%
avg_gpa=r.mean()
print(avg_gpa)
# Out:
# 3.2367816091954027

# %%
sns.distplot(df['Year of Graduation'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16208\2767383942.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Year of Graduation'])
# <Axes: xlabel='Year of Graduation', ylabel='Density'>

# %%
df['Year of Graduation'].sort_values()
# Out:
# 337     2023
# 212     2023
# 271     2023
# 272     2023
# 295     2023
#         ...
# 491     2026
# 351     2026
# 237     2026
# 3627    2026
# 68      2026
# Name: Year of Graduation, Length: 87, dtype: int64

# %%
# 3  Distribution of graduation of year 
bins=[2022,2023,2024,2025,2026,2027]
plt.figure(figsize=(6,4))
sns.set()
sns.distplot(df['Year of Graduation'],bins=bins)
plt.xticks(bins)
plt.title("Distribution of Year Graduation")
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16208\1671292617.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Year of Graduation'],bins=bins)

# %%
sns.distplot(df['Experience with python (Months)'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16208\3294326293.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Experience with python (Months)'])
# <Axes: xlabel='Experience with python (Months)', ylabel='Density'>

# %%
df['Experience with python (Months)'].sort_values()
# Out:
# 1       3
# 4464    3
# 2152    3
# 2160    3
# 295     3
#        ..
# 2417    8
# 2454    8
# 2515    8
# 2323    8
# 2321    8
# Name: Experience with python (Months), Length: 87, dtype: int64

# %%
#4 distribution of experience with python

bins=[2,4,6,8,10]
plt.figure(figsize=(5,4))
sns.set()
sns.distplot(df['Experience with python (Months)'],bins=bins)
plt.xticks(bins)
plt.title("Distribution of Experience with python (Months)")
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16208\549103493.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Experience with python (Months)'],bins=bins)

# %%
# 5 Average Family income of the students
df["Family Income"].replace(["0-2 Lakh","2-5 Lakh","5-7 Lakh","7 Lakh+"],[0,1,2,3],inplace=True)
df
# Out:
#                Email ID  Quantity                       Events  \
# 1     dhanshree@xyz.com         1       Art of Resume Building
# 8      mayuresh@xyz.com         1       Art of Resume Building
# 18      shubham@xyz.com         1       Art of Resume Building
# 20      shivani@xyz.com         1       Art of Resume Building
# 27    dhanshree@xyz.com         1       Art of Resume Building
# ...                 ...       ...                          ...
# 4406      derek@xyz.com         1  Product Design & Full Stack
# 4410    louella@xyz.com         1  Product Design & Full Stack
# 4447    claudia@xyz.com         1  Product Design & Full Stack
# 4464    leeanne@xyz.com         1  Product Design & Full Stack
# 4488       veta@xyz.com         1  Product Design & Full Stack
#
#      Attendee Status                                       College Name  \
# 1          Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
dg=df["Family Income"].mean()
print(dg)
# Out:
# 0.1724137931034483

# %%
# 6 GPA among different colleges
df['GPA']=r
df
# Out:
#                Email ID  Quantity                       Events  \
# 1     dhanshree@xyz.com         1       Art of Resume Building
# 8      mayuresh@xyz.com         1       Art of Resume Building
# 18      shubham@xyz.com         1       Art of Resume Building
# 20      shivani@xyz.com         1       Art of Resume Building
# 27    dhanshree@xyz.com         1       Art of Resume Building
# ...                 ...       ...                          ...
# 4406      derek@xyz.com         1  Product Design & Full Stack
# 4410    louella@xyz.com         1  Product Design & Full Stack
# 4447    claudia@xyz.com         1  Product Design & Full Stack
# 4464    leeanne@xyz.com         1  Product Design & Full Stack
# 4488       veta@xyz.com         1  Product Design & Full Stack
#
#      Attendee Status                                       College Name  \
# 1          Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
df['GPA'].head(5)
# Out:
# 1     3.28
# 8     3.44
# 18    3.64
# 20    3.80
# 27    3.56
# Name: GPA, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 1 to 4488
# Data columns (total 18 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Email ID                                                         87 non-null     object
#  1   Quantity                                                         87 non-null     int64
#  2   Events                                                           87 non-null     object
#  3   Attendee Status                                                  87 non-null     object
#  4   College Name                                                     87 non-null     object
#  5   How did you come to know about this event?                       87 non-null     object
#  6   Specify in "Others" (how did you come to know about this event)  87 non-null     object
# ...

# %%
df.head(5)
# Out:
#              Email ID  Quantity                  Events Attendee Status  \
# 1   dhanshree@xyz.com         1  Art of Resume Building       Attending
# 8    mayuresh@xyz.com         1  Art of Resume Building       Attending
# 18    shubham@xyz.com         1  Art of Resume Building       Attending
# 20    shivani@xyz.com         1  Art of Resume Building       Attending
# 27  dhanshree@xyz.com         1  Art of Resume Building       Attending
#
#                                          College Name  \
# 1                    AP SHAH INSTITUTE OF TECHNOLOGY
# 8                  GOVERNMENT POLYTECHNIC GANDHINAGAR
# 18                                    Wilson college
# 20  DKTE Society's Textile And Engineering Institu...
# 27           Pillai College of Engineering New Panvel
#
#    How did you come to know about this event?  \
# 1                                      Others
# 8                                      Others
# 18                                     Others
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 1 to 4488
# Data columns (total 18 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Email ID                                                         87 non-null     object
#  1   Quantity                                                         87 non-null     int64
#  2   Events                                                           87 non-null     object
#  3   Attendee Status                                                  87 non-null     object
#  4   College Name                                                     87 non-null     object
#  5   How did you come to know about this event?                       87 non-null     object
#  6   Specify in "Others" (how did you come to know about this event)  87 non-null     object
# ...

# %%
df
# Out:
#                Email ID  Quantity                       Events  \
# 1     dhanshree@xyz.com         1       Art of Resume Building
# 8      mayuresh@xyz.com         1       Art of Resume Building
# 18      shubham@xyz.com         1       Art of Resume Building
# 20      shivani@xyz.com         1       Art of Resume Building
# 27    dhanshree@xyz.com         1       Art of Resume Building
# ...                 ...       ...                          ...
# 4406      derek@xyz.com         1  Product Design & Full Stack
# 4410    louella@xyz.com         1  Product Design & Full Stack
# 4447    claudia@xyz.com         1  Product Design & Full Stack
# 4464    leeanne@xyz.com         1  Product Design & Full Stack
# 4488       veta@xyz.com         1  Product Design & Full Stack
#
#      Attendee Status                                       College Name  \
# 1          Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 1 to 4488
# Data columns (total 18 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Email ID                                                         87 non-null     object
#  1   Quantity                                                         87 non-null     int64
#  2   Events                                                           87 non-null     object
#  3   Attendee Status                                                  87 non-null     object
#  4   College Name                                                     87 non-null     object
#  5   How did you come to know about this event?                       87 non-null     object
#  6   Specify in "Others" (how did you come to know about this event)  87 non-null     object
# ...

# %%
#7 Outliers in Attendee status and Quantity
df.boxplot(column='Quantity',by='Attendee Status')
# Out:
# <Axes: title={'center': 'Quantity'}, xlabel='Attendee Status'>

# %%
#8. Relationship between Family income and gpa
df.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16208\4038200327.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                  Quantity  Year of Graduation      CGPA  \
# Quantity                              NaN                 NaN       NaN
# Year of Graduation                    NaN            1.000000  0.074041
# CGPA                                  NaN            0.074041  1.000000
# Experience with python (Months)       NaN           -0.074010 -0.061770
# Family Income                         NaN           -0.255494  0.017880
# Expected salary (Lac)                 NaN            0.285207  0.262679
# GPA                                   NaN            0.074041  1.000000
#
#                                  Experience with python (Months)  \
# ...

# %%
df['Family Income'].corr(df['GPA'])
# Out:
# 0.01787963540023136

# %%
plt.figure(figsize=(3,2))
sns.scatterplot(x="Family Income", y="GPA",data=df)
# Out:
# <Axes: xlabel='Family Income', ylabel='GPA'>
