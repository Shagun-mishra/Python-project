# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Data analyst Data.csv")
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
a=['City']
df.drop(a,inplace=True,axis=1)

# %%
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
df.isnull().sum()
# Out:
# First Name                                                            0
# Email ID                                                              0
# Quantity                                                              0
# Events                                                                0
# Attendee Status                                                       0
# College Name                                                         15
# How did you come to know about this event?                         2216
# Specify in "Others" (how did you come to know about this event)    4805
# Designation                                                           0
# Year of Graduation                                                    0
# CGPA                                                                  0
# Experience with python (Months)                                       0
# Family Income                                                         0
# ...

# %%
s=df.dropna()
s
# Out:
#      First Name           Email ID  Quantity                       Events  \
# 1     Dhanshree  dhanshree@xyz.com         1       Art of Resume Building
# 8      Mayuresh   mayuresh@xyz.com         1       Art of Resume Building
# 18     Shubham     shubham@xyz.com         1       Art of Resume Building
# 20      Shivani    shivani@xyz.com         1       Art of Resume Building
# 27    Dhanshree  dhanshree@xyz.com         1       Art of Resume Building
# ...         ...                ...       ...                          ...
# 4406      Derek      derek@xyz.com         1  Product Design & Full Stack
# 4410    Louella    louella@xyz.com         1  Product Design & Full Stack
# 4447    Claudia    claudia@xyz.com         1  Product Design & Full Stack
# 4464    Leeanne    leeanne@xyz.com         1  Product Design & Full Stack
# 4488       Veta       veta@xyz.com         1  Product Design & Full Stack
#
#      Attendee Status                                       College Name  \
# ...

# %%
s.isnull().sum()
# Out:
# First Name                                                         0
# Email ID                                                           0
# Quantity                                                           0
# Events                                                             0
# Attendee Status                                                    0
# College Name                                                       0
# How did you come to know about this event?                         0
# Specify in "Others" (how did you come to know about this event)    0
# Designation                                                        0
# Year of Graduation                                                 0
# CGPA                                                               0
# Experience with python (Months)                                    0
# Family Income                                                      0
# Expected salary (Lac)                                              0
# ...

# %%
f=s['CGPA']/10*100
q=f/100*4
q.tolist()
# Out:
# [3.28,
#  3.44,
#  3.6399999999999992,
#  3.8,
#  3.56,
#  2.76,
#  2.92,
#  2.68,
#  3.4,
#  3.76,
#  3.08,
#  3.2,
#  2.6,
#  3.76,
#  2.68,
#  2.68,
#  3.16,
#  3.4799999999999995,
#  3.72,
#  2.96,
#  3.28,
#  3.8,
#  3.68,
#  3.8,
#  3.76,
#  3.4,
#  3.08,
#  3.16,
#  3.04,
#  3.6399999999999992,
#  2.76,
#  2.92,
#  3.72,
#  3.12,
#  3.16,
#  2.88,
#  2.84,
#  2.72,
#  2.92,
#  3.32,
#  2.52,
#  2.76,
#  3.88,
#  2.92,
#  3.84,
#  3.0,
#  3.0,
#  3.4799999999999995,
#  2.96,
#  3.96,
#  3.4,
#  3.6399999999999992,
#  2.92,
#  3.16,
#  3.72,
#  3.04,
#  3.4,
#  2.92,
#  3.4,
#  2.52,
#  2.92,
#  2.6,
#  3.72,
#  3.3600000000000008,
#  2.6399999999999992,
#  3.6399999999999992,
#  3.32,
#  3.4799999999999995,
#  3.56,
#  3.04,
#  3.32,
#  3.44,
#  3.6399999999999992,
#  3.2,
#  2.56,
#  3.4799999999999995,
#  3.96,
#  2.92,
#  3.76,
#  3.76,
#  3.04,
#  3.04,
#  2.76,
#  3.68,
#  3.32,
#  2.6,
#  2.84]

# %%
s['GPA']= q
s.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2316\3180061479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['GPA']= q
#    First Name           Email ID  Quantity                  Events  \
# 1   Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 8    Mayuresh   mayuresh@xyz.com         1  Art of Resume Building
# 18   Shubham     shubham@xyz.com         1  Art of Resume Building
# 20    Shivani    shivani@xyz.com         1  Art of Resume Building
# 27  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
#
#    Attendee Status                                       College Name  \
# 1        Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
# 1. Expected salary based on the factors like gpa and Experience with python(Months)
from sklearn import linear_model

X = s[['GPA', 'Experience with python (Months)']]
y = s['Expected salary (Lac)']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [4.45828852 0.22631905]

# %%
s['Events'].describe()
# Out:
# count                         87
# unique                         5
# top       Art of Resume Building
# freq                          57
# Name: Events, dtype: object

# %%
plt.figure(figsize=(5,4))
plt.hist(s['Events'])
# Out:
# (array([57.,  0.,  3.,  0.,  0.,  1.,  0., 19.,  0.,  7.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
f=s['CGPA']/10*100
q=f/100*4
q.tolist()
# Out:
# [3.28,
#  3.44,
#  3.6399999999999992,
#  3.8,
#  3.56,
#  2.76,
#  2.92,
#  2.68,
#  3.4,
#  3.76,
#  3.08,
#  3.2,
#  2.6,
#  3.76,
#  2.68,
#  2.68,
#  3.16,
#  3.4799999999999995,
#  3.72,
#  2.96,
#  3.28,
#  3.8,
#  3.68,
#  3.8,
#  3.76,
#  3.4,
#  3.08,
#  3.16,
#  3.04,
#  3.6399999999999992,
#  2.76,
#  2.92,
#  3.72,
#  3.12,
#  3.16,
#  2.88,
#  2.84,
#  2.72,
#  2.92,
#  3.32,
#  2.52,
#  2.76,
#  3.88,
#  2.92,
#  3.84,
#  3.0,
#  3.0,
#  3.4799999999999995,
#  2.96,
#  3.96,
#  3.4,
#  3.6399999999999992,
#  2.92,
#  3.16,
#  3.72,
#  3.04,
#  3.4,
#  2.92,
#  3.4,
#  2.52,
#  2.92,
#  2.6,
#  3.72,
#  3.3600000000000008,
#  2.6399999999999992,
#  3.6399999999999992,
#  3.32,
#  3.4799999999999995,
#  3.56,
#  3.04,
#  3.32,
#  3.44,
#  3.6399999999999992,
#  3.2,
#  2.56,
#  3.4799999999999995,
#  3.96,
#  2.92,
#  3.76,
#  3.76,
#  3.04,
#  3.04,
#  2.76,
#  3.68,
#  3.32,
#  2.6,
#  2.84]

# %%
s['GPA']= q
s.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2316\3180061479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['GPA']= q
#    First Name           Email ID  Quantity                  Events  \
# 1   Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 8    Mayuresh   mayuresh@xyz.com         1  Art of Resume Building
# 18   Shubham     shubham@xyz.com         1  Art of Resume Building
# 20    Shivani    shivani@xyz.com         1  Art of Resume Building
# 27  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
#
#    Attendee Status                                       College Name  \
# 1        Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
df["Family Income"].replace(["0-2 Lakh","2-5 Lakh","5-7 Lakh","7 Lakh+"],[0,1,2,3],inplace=True)
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
from sklearn import linear_model

X = s[['GPA', 'Experience with python (Months)']]
y = s['Expected salary (Lac)']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [4.45828852 0.22631905]

# %%
#3 Events that attract the students
s['Events'].describe()
# Out:
# count                         87
# unique                         5
# top       Art of Resume Building
# freq                          57
# Name: Events, dtype: object

# %%
plt.hist(s['Events'])
plt.xlabel('Types of Events')
plt.ylabel("Density")
plt.show()

# %%
df['Events'].sort_values()
# Out:
# 0                         Art of Resume Building
# 327                       Art of Resume Building
# 325                       Art of Resume Building
# 324                       Art of Resume Building
# 323                       Art of Resume Building
#                           ...
# 3492    Transformation with DevOps: The Easy Way
# 3493    Transformation with DevOps: The Easy Way
# 3494    Transformation with DevOps: The Easy Way
# 3496    Transformation with DevOps: The Easy Way
# 3465    Transformation with DevOps: The Easy Way
# Name: Events, Length: 4894, dtype: object

# %%
#3  correlation between expected salary and ledership skills
sns.barplot(x='Leadership- skills', y='Expected salary (Lac)', data= s,ci=None)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2316\1332494192.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Leadership- skills', y='Expected salary (Lac)', data= s,ci=None)
# <Axes: xlabel='Leadership- skills', ylabel='Expected salary (Lac)'>

# %%
print(s['Leadership- skills'].corr(s['Expected salary (Lac)'],method='spearman'))        
plt.scatter('x','y')
plt.title('scattered graph for Spearman correlation between Leadership- skills and Expected salary (Lac) ' )
plt.xlabel('Leadership- skills')
plt.ylabel('Expected salary (Lac)')
plt.show()
# Out:
# 0.0663568558588701

# %%
#4 Students that are graduating from 2024
r=s['Year of Graduation'].tolist()
r
# Out:
# [2024,
#  2024,
#  2024,
#  2023,
#  2025,
#  2025,
#  2023,
#  2023,
#  2024,
#  2025,
#  2026,
#  2023,
#  2024,
#  2024,
#  2025,
#  2024,
#  2025,
#  2026,
#  2023,
#  2023,
#  2023,
#  2025,
#  2024,
#  2024,
#  2025,
#  2023,
#  2024,
#  2024,
#  2024,
#  2025,
#  2026,
#  2024,
#  2024,
#  2025,
#  2024,
#  2023,
#  2023,
#  2024,
#  2025,
#  2023,
#  2024,
#  2025,
#  2025,
#  2023,
#  2026,
#  2025,
#  2026,
#  2024,
#  2025,
#  2025,
#  2025,
#  2024,
#  2023,
#  2026,
#  2026,
#  2025,
#  2025,
#  2024,
#  2024,
#  2023,
#  2026,
#  2025,
#  2023,
#  2023,
#  2025,
#  2025,
#  2025,
#  2023,
#  2025,
#  2025,
#  2023,
#  2023,
#  2024,
#  2023,
#  2024,
#  2024,
#  2023,
#  2025,
#  2026,
#  2023,
#  2024,
#  2025,
#  2024,
#  2025,
#  2025,
#  2023,
#  2023]

# %%
d=r.count(2024)
print(d)
# Out:
# 26

# %%
#5 Promotional chaannel thatas bring more students
plt.figure(figsize=(7,6))
plt.hist(s["How did you come to know about this event?"])
plt.xlabel('Types of Promotional channel')
plt.ylabel('Density')
plt.show()

# %%
#6 Total no. of students that attend data science events
t=s['Events']
t.tolist()
# Out:
# ['Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
#  'Art of Resume Building',
# ...

# %%
for l in t:
    if l=='Data Visualization using Power BI':
        print(l)
    elif l=='Transformation with DevOps: The Easy Way':
        print(l)
# Out:
# Data Visualization using Power BI
# Data Visualization using Power BI
# Data Visualization using Power BI
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way
# Transformation with DevOps: The Easy Way

# %%
#7 Those who have high CGPA and experience than high expectations for salary
b= s['CGPA' and'Experience with python (Months)'].mean()
print(b)
# Out:
# 5.0344827586206895

# %%
n= s['Expected salary (Lac)'].mean()
print(n)
# Out:
# 13.402298850574713

# %%
#8 Students that know about the events from their colleges 
s['College Name'].head(5)
# Out:
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY
# 8                    GOVERNMENT POLYTECHNIC GANDHINAGAR
# 18                                      Wilson college
# 20    DKTE Society's Textile And Engineering Institu...
# 27             Pillai College of Engineering New Panvel
# Name: College Name, dtype: object
